# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahYLawrence/Implementing-Iterative-Methods/blob/Code-Phase/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
function spd_matrix(n, cond)
    # Generate a random orthogonal matrix
    Q, _ = qr(randn(n, n))
    # Generate positive eigenvalues with a given condition number
    λ_min = 1.0
    λ_max = cond
    λ = range(λ_min, λ_max, length=n)
    D = Diagonal(λ)
    # Construct SPD matrix: A = Q * D * Q'
    A = Q * D * Q'
    return Symmetric(A)
end
# Out:
# spd_matrix (generic function with 1 method)

# %%
# conjugate gradient
function conjugate_gradient(A, b; x0=zero(b), tol=1e-8, maxiter=1000)
    x = copy(x0) # current estimate
    r = b - A * x # residual: how far x is from the true solution
    p = copy(r) # search direction
    rs_old = dot(r, r) # squared norm of the residual

    residuals = [sqrt(rs_old)] # store the first residual

    for k in 1:maxiter
        Ap = A * p  # determine the best step size
        alpha = rs_old / dot(p, Ap) # optimal step length along direction p
        x += alpha * p # move in direction p by amount α
        r -= alpha * Ap # update residual

        # Check Convergence: If residual norm is small enough, CG has converged
        rs_new = dot(r, r)
        push!(residuals, sqrt(rs_new))
        if sqrt(rs_new) < tol
            println("Converged in $k iterations")
            return x
        end

        beta = rs_new / rs_old  # how much of the previous direction is kept

        # Update Search Direction
        p = r + beta * p
        rs_old = rs_new
    end
    # incase max iterations are reached
    println("Max iterations reached")
    return x, residuals
end
# Out:
# conjugate_gradient (generic function with 1 method)

# %%
using Random, LinearAlgebra

# Fix the seed
Random.seed!(123)  # <- same seed every time

# Define your SPD matrices and vector b
n = 5
A1 = spd_matrix(n, 10)
A2 = spd_matrix(n, 1000)
A3 = spd_matrix(n, 10000000)
b = randn(n)  # this will always be the same with the same seed

# Run conjugate gradient
x1, res1 = conjugate_gradient(A1, b)
x2, res2 = conjugate_gradient(A2, b)
x3, res3 = conjugate_gradient(A3, b)
# Out:
# Converged in 5 iterations
# Converged in 5 iterations
# Converged in 6 iterations
# 5-element Vector{Float64}:
#  -0.27415982529944183
#   0.299153612168632
#  -0.24148690370867093
#  -0.2276383249799407
#   0.18287179081250154

# %%
using Plots

x1, res1 = conjugate_gradient_residuals(A1, b)
x2, res2 = conjugate_gradient_residuals(A2, b)
x3, res3 = conjugate_gradient_residuals(A3, b)

plt = plot(1:length(res1), res1, yscale=:log10, label="cond=10",
           xlabel="Iteration", ylabel="Residual ||r||")
plot!(plt, 1:length(res2), res2, label="cond=1000")
plot!(plt, 1:length(res3), res3, label="cond=10000000")

# Save the plot as a PNG (or PDF, SVG, etc.)
savefig(plt, "cg_residuals.png")
# Out:
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] (cache misses: wrong dep version loaded (2))
#
# [1844] signal 2: Interrupt
# in expression starting at /root/.julia/packages/Plots/8ZnR3/src/types.jl:21
# InterruptException:
#
# Stacktrace:
#   [1] poptask(W::Base.IntrusiveLinkedListSynchronized{Task})
#     @ Base ./task.jl:1012
#   [2] wait()
#     @ Base ./task.jl:1021
#   [3] wait(c::Base.GenericCondition{Base.Threads.SpinLock}; first::Bool)
#     @ Base ./condition.jl:130
#   [4] wait
#     @ ./condition.jl:125 [inlined]
#   [5] wait(x::Base.Process, syncd::Bool)
#     @ Base ./process.jl:694
#   [6] wait
#     @ ./process.jl:687 [inlined]
#   [7] success(x::Base.Process)
#     @ Base ./process.jl:556
#   [8] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Nothing)
#     @ Base ./loading.jl:3082
#   [9] (::Base.var"#1110#1111"{Base.PkgId})()
#     @ Base ./loading.jl:2579
#  [10] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile /usr/local/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
#  [11] #mkpidlock#6
#     @ /usr/local/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
#  [12] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile /usr/local/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
#  [13] #invokelatest#2
#     @ ./essentials.jl:1057 [inlined]
#  [14] invokelatest
#     @ ./essentials.jl:1052 [inlined]
#  [15] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base ./loading.jl:3698
#  [16] maybe_cachefile_lock
#     @ ./loading.jl:3695 [inlined]
#  [17] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:2565
#  [18] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2388
#  [19] #invoke_in_world#3
#     @ ./essentials.jl:1089 [inlined]
#  [20] invoke_in_world
#     @ ./essentials.jl:1086 [inlined]
#  [21] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2375
#  [22] macro expansion
#     @ ./loading.jl:2314 [inlined]
#  [23] macro expansion
#     @ ./lock.jl:273 [inlined]
#  [24] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2271
#  [25] #invoke_in_world#3
#     @ ./essentials.jl:1089 [inlined]
#  [26] invoke_in_world
#     @ ./essentials.jl:1086 [inlined]
#  [27] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2260

# %%
using LinearAlgebra

function gmres_residuals(A, b; x0=zero(b), tol=1e-8, maxiter=100)
    n = length(b) # number of entries in the vector b
    x = copy(x0) # current estimate
    r0 = b - A*x # initial residual
    beta = norm(r0) # magnitude of that initial error

    residuals = [beta] # residuals array stores the norms at each step

    # immediately exits if the initial guess is already accurate
    if beta < tol
        return x, residuals
    end

    # Arnoldi process
    V = zeros(n, maxiter+1) # basis vectors
    H = zeros(maxiter+1, maxiter) # upper Hessenberg matrix
    V[:,1] = r0 / beta # orthonormal basis vector

    for j in 1:maxiter
        w = A * V[:,j]
        # modified Gram–Schmidt
        for i in 1:j
            H[i,j] = dot(V[:,i], w)
            w -= H[i,j] * V[:,i]
        end
        # new basis vector
        H[j+1,j] = norm(w)
        if H[j+1,j] != 0
            V[:,j+1] = w / H[j+1,j]
        end

        # solve least squares min ||beta e1 - H y||
        e1 = zeros(j+1); e1[1] = beta
        y = H[1:j+1,1:j] \ e1
        x_approx = x0 + V[:,1:j]*y

        # residual norm for plotting
        res = norm(b - A*x_approx)
        push!(residuals, res)

        # check convergence
        if res < tol
            println("GMRES converged in $j iterations")
            return x_approx, residuals
        end
    end
    println("GMRES max iterations reached")
    return x_approx, residuals
end
# Out:
# gmres_residuals (generic function with 1 method)

# %%
using Random

n = 5
Random.seed!(123)

A1 = spd_matrix(n, 10)    # well-conditioned
A2 = spd_matrix(n, 1000)  # ill-conditioned
A3 = spd_matrix(n, 10000000)  # ill-conditioned
b = randn(n)

x1, res1 = gmres_residuals(A1, b)
x2, res2 = gmres_residuals(A2, b)
x3, res3 = gmres_residuals(A3, b)
# Out:
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# ([-0.2741598252356262, 0.299153612098999, -0.24148690365246064, -0.2276383249269539, 0.18287179076993482], [1.70277456031669, 0.5912550235929177, 0.5587983440652987, 0.555192328203559, 0.5551875360070435, 1.3121926950500375e-9])

# %%
using Plots


x1, res1 = gmres_residuals(A1, b)
x2, res2 = gmres_residuals(A2, b)
x3, res3 = gmres_residuals(A3, b)

plt = plot(1:length(res1), res1, yscale=:log10, label="cond=10", xlabel="Iteration", ylabel="Residual ||r||")
plot!(plt, 1:length(res2), res2, label="cond=1000")  # yscale log10 already set
plot!(plt, 1:length(res3), res3, label="cond=10000000")  # yscale log10 already set

savefig(plt, "gmres_residuals.png")
# Out:
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# "/content/gmres_residuals.png"

# %%
using LinearAlgebra

function bicgstab_residuals(A, b; x0=zero(b), tol=1e-8, maxiter=1000)
    n = length(b)
    x = copy(x0) # current approximation of the solution
    r = b - A*x # residual
    r_hat = copy(r) # fixed copy of the initial residual (used for or computing scalars)
    rho_old = alpha = omega = 1.0 # scalars initialized to 1
    v = zeros(n) #  auxiliary vector used in the iterations
    p = zeros(n) # auxiliary vector used in the iterations

    residuals = [norm(r)] # list storing the norm of the residual at each step

    for k in 1:maxiter
        rho = dot(r_hat, r) # control the search direction update
        # the method breaks down because a division by zero
        if rho == 0
            println("Breakdown: rho=0")
            break
        end
        # update the search direction p
        if k == 1
            p = r
        else
            beta = (rho/rho_old) * (alpha/omega)
            p = r + beta*(p - omega*v)
        end

        v = A*p # matrix-vector product
        alpha = rho / dot(r_hat, v) # reduce the residual in the current direction
        s = r - alpha*v # residual after moving
        t = A*s # stabilize the correction step
        omega = dot(t,s)/dot(t,t)
        x += alpha*p + omega*s
        r = s - omega*t

        push!(residuals, norm(r)) # residual norm is saved for plotting or analysis.

        # if residual is below the tolerance then stop
        if norm(r) < tol
            println("BiCGSTAB converged in $k iterations")
            return x, residuals
        end

        # check breakdown
        # if omega = 0, the algorithm cannot continue.
        if omega == 0
            println("Breakdown: omega=0")
            break
        end

        rho_old = rho # is updated for the next iteration
    end
    println("BiCGSTAB max iterations reached")
    return x, residuals
end
# Out:
# bicgstab_residuals (generic function with 1 method)

# %%
Random.seed!(123)

A1 = spd_matrix(n, 10)    # well-conditioned
A2 = spd_matrix(n, 1000)  # ill-conditioned
A3 = spd_matrix(n, 10000000)
b = randn(n)

x1, res1 = bicgstab_residuals(A1, b)
x2, res2 = bicgstab_residuals(A2, b)
x3, res3 = bicgstab_residuals(A3, b)
# Out:
# BiCGSTAB converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# ([-0.2741598268039143, 0.2991536138102591, -0.24148690503384795, -0.22763832622912222, 0.1828717918160246], [1.70277456031669, 0.558808851953471, 0.577422216863759, 0.5774852931976713, 0.5628588533250882, 3.095944622007877e-9])

# %%
using Plots
gr()

x1, res1 = bicgstab_residuals(A1, b)
x2, res2 = bicgstab_residuals(A2, b)
x3, res3 = bicgstab_residuals(A3, b)

plt = plot(1:length(res1), res1, yscale=:log10, label="cond=10", xlabel="Iteration", ylabel="Residual ||r||")
plot!(plt, 1:length(res2), res2, label="cond=1000")  # yscale log10 already set
plot!(plt, 1:length(res3), res3, label="cond=10000000")  # yscale log10 already set

display(plt)  # shows the plot in a window
savefig(plt, "bicgstab_residuals.png")
# Out:
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] (cache misses: wrong dep version loaded (2))
#
# [1320] signal 2: Interrupt
# in expression starting at /root/.julia/packages/libass_jll/nCs3D/src/wrappers/x86_64-linux-gnu.jl:6
# epoll_pwait at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# uv__io_poll at /workspace/srcdir/libuv/src/unix/linux.c:1404
#
# [1312] signal 2: Interrupt
# in expression starting at /root/.julia/packages/FFMPEG_jll/8pVH6/src/wrappers/x86_64-linux-gnu.jl:4
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:430
# epoll_pwait at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
#
# [1276] signal 2: Interrupt
# in expression starting at /root/.julia/packages/Plots/8ZnR3/src/animation.jl:1
# epoll_pwait at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
#
# [1308] signal 2: Interrupt
# in expression starting at /root/.julia/packages/FFMPEG/a6NkO/src/FFMPEG.jl:3
# epoll_pwait at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
#
# [1324] signal 2: Interrupt
# in expression starting at /root/.julia/packages/HarfBuzz_jll/7bm66/src/wrappers/x86_64-linux-gnu.jl:4
# epoll_pwait at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# uv__io_poll at /workspace/srcdir/libuv/src/unix/linux.c:1404
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:430
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# uv__io_poll at /workspace/srcdir/libuv/src/unix/linux.c:1404
# uv__io_poll at /workspace/srcdir/libuv/src/unix/linux.c:1404
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:430
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:430
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# uv__io_poll at /workspace/srcdir/libuv/src/unix/linux.c:1404
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:430
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
#
# [1328] signal 2: Interrupt
# in expression starting at /root/.julia/packages/Cairo_jll/9xtvE/src/wrappers/x86_64-linux-gnu.jl:4
# _ZN4llvm5Value6doRAUWEPS0_NS0_19ReplaceMetadataUsesE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# poptask at ./task.jl:1012
# poptask at ./task.jl:1012
# poptask at ./task.jl:1012
# wait at ./task.jl:1021
# wait at ./task.jl:1021
# poptask at ./task.jl:1012
# poptask at ./task.jl:1012
# wait at ./task.jl:1021
# #wait#731 at ./condition.jl:130
# #wait#731 at ./condition.jl:130
# wait at ./task.jl:1021
# wait at ./task.jl:1021
# #wait#731 at ./condition.jl:130
# wait at ./condition.jl:125 [inlined]
# wait at ./process.jl:694
# wait at ./condition.jl:125 [inlined]
# wait at ./process.jl:694
# CleanupIR at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/llvm-late-gc-lowering.cpp:2547
# runOnFunction at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/llvm-late-gc-lowering.cpp:2826
# runOnFunction at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/llvm-late-gc-lowering.cpp:2818 [inlined]
# run at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/llvm-late-gc-lowering.cpp:2837
# #wait#731 at ./condition.jl:130
# #wait#731 at ./condition.jl:130
# wait at ./condition.jl:125 [inlined]
# wait at ./process.jl:694
# wait at ./process.jl:687 [inlined]
# success at ./process.jl:556
# wait at ./process.jl:687 [inlined]
# success at ./process.jl:556
# wait at ./condition.jl:125 [inlined]
# wait at ./process.jl:694
# wait at ./condition.jl:125 [inlined]
# wait at ./process.jl:694
# wait at ./process.jl:687 [inlined]
# success at ./process.jl:556
# run at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/include/llvm/IR/PassManagerInternal.h:89
# run at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/include/llvm/IR/PassManager.h:517 [inlined]
# run at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/include/llvm/IR/PassManagerInternal.h:89
# _ZN4llvm27ModuleToFunctionPassAdaptor3runERNS_6ModuleERNS_15AnalysisManagerIS1_JEEE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# wait at ./process.jl:687 [inlined]
# success at ./process.jl:556
# run at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/include/llvm/IR/PassManagerInternal.h:89
# wait at ./process.jl:687 [inlined]
# success at ./process.jl:556
# run at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/include/llvm/IR/PassManager.h:517 [inlined]
# run at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/pipeline.cpp:777
# operator() at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jitlayers.cpp:1298
# withModuleDo<(anonymous namespace)::OptimizerT<N>::operator()(llvm::orc::ThreadSafeModule, llvm::orc::MaterializationResponsibility&) [with long unsigned int N = 4]::<lambda(llvm::Module&)> > at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/include/llvm/ExecutionEngine/Orc/ThreadSafeModule.h:136 [inlined]
# operator() at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jitlayers.cpp:1259 [inlined]
# CallImpl<(anonymous namespace)::OptimizerT<4> > at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/include/llvm/ADT/FunctionExtras.h:221
# _ZN4llvm3orc16IRTransformLayer4emitESt10unique_ptrINS0_29MaterializationResponsibilityESt14default_deleteIS3_EENS0_16ThreadSafeModuleE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc16IRTransformLayer4emitESt10unique_ptrINS0_29MaterializationResponsibilityESt14default_deleteIS3_EENS0_16ThreadSafeModuleE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc16IRTransformLayer4emitESt10unique_ptrINS0_29MaterializationResponsibilityESt14default_deleteIS3_EENS0_16ThreadSafeModuleE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc31BasicIRLayerMaterializationUnit11materializeESt10unique_ptrINS0_29MaterializationResponsibilityESt14default_deleteIS3_EE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc19MaterializationTask3runEv at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm6detail18UniqueFunctionBaseIvJSt10unique_ptrINS_3orc4TaskESt14default_deleteIS4_EEEE8CallImplIPFvS7_EEEvPvRS7_ at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc16ExecutionSession22dispatchOutstandingMUsEv at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc16ExecutionSession17OL_completeLookupESt10unique_ptrINS0_21InProgressLookupStateESt14default_deleteIS3_EESt10shared_ptrINS0_23AsynchronousSymbolQueryEESt8functionIFvRKNS_8DenseMapIPNS0_8JITDylibENS_8DenseSetINS0_15SymbolStringPtrENS_12DenseMapInfoISF_vEEEENSG_ISD_vEENS_6detail12DenseMapPairISD_SI_EEEEEE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# jfptr_success_67764.1 at /usr/local/lib/julia/sys.so (unknown line)
# #compilecache#1121 at ./loading.jl:3082
# compilecache at ./loading.jl:3038
# compilecache at ./loading.jl:3038
# unknown function (ip: 0x7ce57f70117d)
# jfptr_success_67764.1 at /usr/local/lib/julia/sys.so (unknown line)
# _ZN4llvm3orc25InProgressFullLookupState8completeESt10unique_ptrINS0_21InProgressLookupStateESt14default_deleteIS3_EE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc16ExecutionSession19OL_applyQueryPhase1ESt10unique_ptrINS0_21InProgressLookupStateESt14default_deleteIS3_EENS_5ErrorE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc16ExecutionSession6lookupENS0_10LookupKindERKSt6vectorISt4pairIPNS0_8JITDylibENS0_19JITDylibLookupFlagsEESaIS8_EENS0_15SymbolLookupSetENS0_11SymbolStateENS_15unique_functionIFvNS_8ExpectedINS_8DenseMapINS0_15SymbolStringPtrENS_18JITEvaluatedSymbolENS_12DenseMapInfoISI_vEENS_6detail12DenseMapPairISI_SJ_EEEEEEEEESt8functionIFvRKNSH_IS6_NS_8DenseSetISI_SL_EENSK_IS6_vEENSN_IS6_SV_EEEEEE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# _ZN4llvm3orc16ExecutionSession6lookupERKSt6vectorISt4pairIPNS0_8JITDylibENS0_19JITDylibLookupFlagsEESaIS7_EENS0_15SymbolLookupSetENS0_10LookupKindENS0_11SymbolStateESt8functionIFvRKNS_8DenseMapIS5_NS_8DenseSetINS0_15SymbolStringPtrENS_12DenseMapInfoISI_vEEEENSJ_IS5_vEENS_6detail12DenseMapPairIS5_SL_EEEEEE at /usr/local/bin/../lib/julia/libLLVM-16jl.so (unknown line)
# #1110 at ./loading.jl:2579
# #mkpidlock#7 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
# unknown function (ip: 0x7ce57f700b63)
# addModule at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jitlayers.cpp:1875
# jl_add_to_ee at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jitlayers.cpp:2306
# _jl_compile_codeinst at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jitlayers.cpp:277
# jl_generate_fptr_impl at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jitlayers.cpp:536
# jl_compile_method_internal at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/gf.c:2536 [inlined]
# jl_compile_method_internal at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/gf.c:2423
# _jl_invoke at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/gf.c:2940 [inlined]
# ijl_apply_generic at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/gf.c:3125
# macro expansion at /root/.julia/packages/JLLWrappers/m2Pjh/src/wrapper_generators.jl:64 [inlined]
# __init__ at /root/.julia/packages/Libiconv_jll/sE4g7/src/wrappers/x86_64-linux-gnu.jl:21
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_module_run_initializer at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:76
# jfptr_success_67764.1 at /usr/local/lib/julia/sys.so (unknown line)
# #compilecache#1121 at ./loading.jl:3082
# jfptr_success_67764.1 at /usr/local/lib/julia/sys.so (unknown line)
# compilecache at ./loading.jl:3038
# compilecache at ./loading.jl:3038
# unknown function (ip: 0x790d86ccf2bd)
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:92
# jfptr_success_67764.1 at /usr/local/lib/julia/sys.so (unknown line)
# #compilecache#1121 at ./loading.jl:3082
# compilecache at ./loading.jl:3038
# compilecache at ./loading.jl:3038
# unknown function (ip: 0x7b14e0cd186d)
# #1110 at ./loading.jl:2579
# #mkpidlock#7 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
# unknown function (ip: 0x790d86cceca3)
# #compilecache#1121 at ./loading.jl:3082
# compilecache at ./loading.jl:3038
# compilecache at ./loading.jl:3038
# unknown function (ip: 0x7d79b930520d)
# #compilecache#1121 at ./loading.jl:3082
# #mkpidlock#6 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90
# compilecache at ./loading.jl:3038
# compilecache at ./loading.jl:3038
# unknown function (ip: 0x79bff67c934d)
# #1110 at ./loading.jl:2579
# #mkpidlock#7 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
# unknown function (ip: 0x79bff67c8d33)
# #1110 at ./loading.jl:2579
# #mkpidlock#7 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
# unknown function (ip: 0x7b14e0cd1253)
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:92
# #1110 at ./loading.jl:2579
# #mkpidlock#7 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
# unknown function (ip: 0x7d79b9304bf3)
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:92
# run_module_init at ./loading.jl:1378
# jfptr_mkpidlock_44807.1 at /usr/local/lib/julia/sys.so (unknown line)
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:92
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# #mkpidlock#6 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:92
# #mkpidlock#6 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90
# register_restored_modules at ./loading.jl:1366
# #mkpidlock#6 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90
# #trymkpidlock#11 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# #mkpidlock#6 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
# mkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90
# jfptr_mkpidlock_44807.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# #_include_from_serialized#1082 at ./loading.jl:1254
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# jfptr_mkpidlock_44807.1 at /usr/local/lib/julia/sys.so (unknown line)
# trymkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:114
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_latest at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:875
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# jfptr_mkpidlock_44807.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jfptr_mkpidlock_44807.1 at /usr/local/lib/julia/sys.so (unknown line)
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# #trymkpidlock#11 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
# _include_from_serialized at ./loading.jl:1210 [inlined]
# _include_from_serialized at ./loading.jl:1210 [inlined]
# #_require_search_from_serialized#1105 at ./loading.jl:2041
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# #trymkpidlock#11 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
# #invokelatest#2 at ./essentials.jl:1057 [inlined]
# invokelatest at ./essentials.jl:1052 [inlined]
# #maybe_cachefile_lock#1131 at ./loading.jl:3698
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# #trymkpidlock#11 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# _require_search_from_serialized at ./loading.jl:1969
# trymkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:114
# #trymkpidlock#11 at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_latest at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:875
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:831
# trymkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:114
# maybe_cachefile_lock at ./loading.jl:3695 [inlined]
# _require at ./loading.jl:2565
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_latest at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:875
# trymkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:114
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_latest at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:875
# #invokelatest#2 at ./essentials.jl:1057 [inlined]
# invokelatest at ./essentials.jl:1052 [inlined]
# #maybe_cachefile_lock#1131 at ./loading.jl:3698
# trymkpidlock at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/usr/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:114
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_latest at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:875
# __require_prelocked at ./loading.jl:2388
# #invokelatest#2 at ./essentials.jl:1057 [inlined]
# invokelatest at ./essentials.jl:1052 [inlined]
# #maybe_cachefile_lock#1131 at ./loading.jl:3698
# #invokelatest#2 at ./essentials.jl:1057 [inlined]
# invokelatest at ./essentials.jl:1052 [inlined]
# #maybe_cachefile_lock#1131 at ./loading.jl:3698
# maybe_cachefile_lock at ./loading.jl:3695 [inlined]
# _require at ./loading.jl:2565
# #invokelatest#2 at ./essentials.jl:1057 [inlined]
# invokelatest at ./essentials.jl:1052 [inlined]
# #maybe_cachefile_lock#1131 at ./loading.jl:3698
# maybe_cachefile_lock at ./loading.jl:3695 [inlined]
# _require at ./loading.jl:2565
# jfptr___require_prelocked_71186.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# maybe_cachefile_lock at ./loading.jl:3695 [inlined]
# _require at ./loading.jl:2565
# __require_prelocked at ./loading.jl:2388
# maybe_cachefile_lock at ./loading.jl:3695 [inlined]
# _require at ./loading.jl:2565
# __require_prelocked at ./loading.jl:2388
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# _require_prelocked at ./loading.jl:2375
# __require_prelocked at ./loading.jl:2388
# __require_prelocked at ./loading.jl:2388
# jfptr___require_prelocked_71186.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# macro expansion at ./loading.jl:2314 [inlined]
# jfptr___require_prelocked_71186.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# macro expansion at ./lock.jl:273 [inlined]
# __require at ./loading.jl:2271
# jfptr___require_prelocked_71186.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# jfptr___require_prelocked_71186.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# _require_prelocked at ./loading.jl:2375
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# _require_prelocked at ./loading.jl:2375
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# _require_prelocked at ./loading.jl:2375
# jfptr___require_71117.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# jfptr__require_search_from_serialized_44910.1 at /usr/local/lib/julia/sys.so (unknown line)
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# _require_prelocked at ./loading.jl:2375
# macro expansion at ./loading.jl:2314 [inlined]
# macro expansion at ./lock.jl:273 [inlined]
# __require at ./loading.jl:2271
# macro expansion at ./loading.jl:2314 [inlined]
# macro expansion at ./lock.jl:273 [inlined]
# __require at ./loading.jl:2271
# macro expansion at ./loading.jl:2314 [inlined]
# macro expansion at ./lock.jl:273 [inlined]
# __require at ./loading.jl:2271
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# require at ./loading.jl:2260
# macro expansion at ./loading.jl:2314 [inlined]
# macro expansion at ./lock.jl:273 [inlined]
# __require at ./loading.jl:2271
# _require at ./loading.jl:2527
# jfptr___require_71117.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# jfptr___require_71117.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# jfptr___require_71117.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# __require_prelocked at ./loading.jl:2388
# jfptr_require_71114.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# call_require at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:486 [inlined]
# eval_import_path at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:523
# jfptr___require_71117.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# require at ./loading.jl:2260
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:759
# invoke_in_world at ./essentials.jl:1086 [inlined]
# require at ./loading.jl:2260
# jl_eval_module_expr at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:215 [inlined]
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:743
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# require at ./loading.jl:2260
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# require at ./loading.jl:2260
# jfptr___require_prelocked_71186.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# jfptr_require_71114.1 at /usr/local/lib/julia/sys.so (unknown line)
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# jfptr_require_71114.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# call_require at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:486 [inlined]
# eval_import_path at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:523
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# call_require at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:486 [inlined]
# eval_import_path at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:523
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:759
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:759
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jfptr_require_71114.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# call_require at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:486 [inlined]
# eval_import_path at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:523
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# jfptr_require_71114.1 at /usr/local/lib/julia/sys.so (unknown line)
# invoke_in_world at ./essentials.jl:1086 [inlined]
# _require_prelocked at ./loading.jl:2375
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:759
# _include at ./loading.jl:2794
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# call_require at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:486 [inlined]
# eval_import_path at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:523
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:759
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# macro expansion at ./loading.jl:2314 [inlined]
# macro expansion at ./lock.jl:273 [inlined]
# __require at ./loading.jl:2271
# include at ./Base.jl:557 [inlined]
# include_package_for_output at ./loading.jl:2881
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# _include at ./loading.jl:2794
# _include at ./loading.jl:2794
# _include at ./loading.jl:2794
# jfptr___require_71117.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_in_world at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:894
# jfptr_include_package_for_output_72111.1 at /usr/local/lib/julia/sys.so (unknown line)
# include at ./Base.jl:557
# _include at ./loading.jl:2794
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# include at ./Base.jl:557
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# include at ./Base.jl:557
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# #invoke_in_world#3 at ./essentials.jl:1089 [inlined]
# invoke_in_world at ./essentials.jl:1086 [inlined]
# require at ./loading.jl:2260
# include at ./Base.jl:557
# jfptr_include_46879.1 at /usr/local/lib/julia/sys.so (unknown line)
# jfptr_include_46879.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# jfptr_require_71114.1 at /usr/local/lib/julia/sys.so (unknown line)
# jfptr_include_46879.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_f__call_latest at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/builtins.c:875
# include at /root/.julia/packages/Plots/8ZnR3/src/Plots.jl:1
# unknown function (ip: 0x79bff6709042)
# jl_eval_module_expr at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:215 [inlined]
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:743
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# call_require at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:486 [inlined]
# eval_import_path at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:523
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:759
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_eval_module_expr at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:215 [inlined]
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:743
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jfptr_include_46879.1 at /usr/local/lib/julia/sys.so (unknown line)
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# include_string at ./loading.jl:2744 [inlined]
# exec_options at ./client.jl:321
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_eval_module_expr at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:215 [inlined]
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:743
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# jl_eval_module_expr at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:215 [inlined]
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:743
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# eval at ./boot.jl:430 [inlined]
# _start at ./client.jl:531
# include_string at ./loading.jl:2734
# _include at ./loading.jl:2794
# _include at ./loading.jl:2794
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# _include at ./loading.jl:2794
# jfptr__start_73430.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# true_main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:900
# jl_repl_entrypoint at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:1059
# main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/cli/loader_exe.c:58
# unknown function (ip: 0x7ce59996fd8f)
# __libc_start_main at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# unknown function (ip: 0x4010b8)
# unknown function (ip: (nil))
# Allocations: 1 (Pool: 1; Big: 0); GC: 0
# include at ./Base.jl:557 [inlined]
# include_package_for_output at ./loading.jl:2881
# _include at ./loading.jl:2794
# _include at ./loading.jl:2794
# include at ./Base.jl:557 [inlined]
# include_package_for_output at ./loading.jl:2881
# val already in a list
# atexit hook threw an error: ErrorException("schedule: Task not runnable")
# include at ./Base.jl:557
# include at ./Base.jl:557 [inlined]
# include_package_for_output at ./loading.jl:2881
# jfptr_include_package_for_output_72111.1 at /usr/local/lib/julia/sys.so (unknown line)
# error at ./error.jl:35
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# include at ./Base.jl:557 [inlined]
# include_package_for_output at ./loading.jl:2881
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# jfptr_include_package_for_output_72111.1 at /usr/local/lib/julia/sys.so (unknown line)
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# #schedule#761 at ./task.jl:884
# jfptr_include_46879.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jfptr_include_package_for_output_72070.1 at /usr/local/lib/julia/sys.so (unknown line)
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# jfptr_include_package_for_output_72111.1 at /usr/local/lib/julia/sys.so (unknown line)
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_eval_module_expr at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:215 [inlined]
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:743
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# schedule at ./task.jl:876 [inlined]
# uv_writecb_task at ./stream.jl:1200
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# jfptr_uv_writecb_task_66985.1 at /usr/local/lib/julia/sys.so (unknown line)
# include_string at ./loading.jl:2744 [inlined]
# exec_options at ./client.jl:321
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# include_string at ./loading.jl:2744 [inlined]
# exec_options at ./client.jl:321
# _include at ./loading.jl:2794
# _start at ./client.jl:531
# include_string at ./loading.jl:2744 [inlined]
# exec_options at ./client.jl:321
# jlcapi_uv_writecb_task_67448.1 at /usr/local/lib/julia/sys.so (unknown line)
# uv__write_callbacks at /workspace/srcdir/libuv/src/unix/stream.c:926
# uv__stream_io at /workspace/srcdir/libuv/src/unix/stream.c:1227
# include_string at ./loading.jl:2744 [inlined]
# exec_options at ./client.jl:321
# _start at ./client.jl:531
# uv__run_pending at /workspace/srcdir/libuv/src/unix/core.c:824
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:420
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# include at ./Base.jl:557 [inlined]
# include_package_for_output at ./loading.jl:2881
# _start at ./client.jl:531
# jfptr__start_73430.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# true_main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:900
# jl_repl_entrypoint at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:1059
# main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/cli/loader_exe.c:58
# unknown function (ip: 0x790d9e049d8f)
# __libc_start_main at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# unknown function (ip: 0x4010b8)
# unknown function (ip: (nil))
# Allocations: 1 (Pool: 1; Big: 0); GC: 0
# _start at ./client.jl:531
# jfptr__start_73430.1 at /usr/local/lib/julia/sys.so (unknown line)
# poptask at ./task.jl:1012
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# true_main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:900
# jl_repl_entrypoint at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:1059
# main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/cli/loader_exe.c:58
# unknown function (ip: 0x7d79d354bd8f)
# __libc_start_main at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# unknown function (ip: 0x4010b8)
# unknown function (ip: (nil))
# Allocations: 1 (Pool: 1; Big: 0); GC: 0
# val already in a list
# atexit hook threw an error: ErrorException("schedule: Task not runnable")
# jfptr_include_package_for_output_72111.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# do_call at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:126
# jfptr__start_73430.1 at /usr/local/lib/julia/sys.so (unknown line)
# eval_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:223
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# true_main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:900
# jl_repl_entrypoint at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:1059
# main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/cli/loader_exe.c:58
# unknown function (ip: 0x79c0109d8d8f)
# __libc_start_main at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# unknown function (ip: 0x4010b8)
# unknown function (ip: (nil))
# Allocations: 8888478 (Pool: 8888155; Big: 323); GC: 9
# val already in a list
# atexit hook threw an error: ErrorException("schedule: Task not runnable")
# eval_stmt_value at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:174 [inlined]
# eval_body at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:666
# wait at ./task.jl:1021
# jl_interpret_toplevel_thunk at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/interpreter.c:824
# jfptr__start_73430.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:943
# jl_toplevel_eval_flex at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:886
# ijl_toplevel_eval_in at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/toplevel.c:994
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# true_main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:900
# jl_repl_entrypoint at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:1059
# main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/cli/loader_exe.c:58
# unknown function (ip: 0x7b14f8000d8f)
# __libc_start_main at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# unknown function (ip: 0x4010b8)
# unknown function (ip: (nil))
# Allocations: 1 (Pool: 1; Big: 0); GC: 0
# error at ./error.jl:35
# error at ./error.jl:35
# uv_write at ./stream.jl:1081
# eval at ./boot.jl:430 [inlined]
# include_string at ./loading.jl:2734
# val already in a list
# atexit hook threw an error: ErrorException("schedule: Task not runnable")
# #schedule#761 at ./task.jl:884
# #schedule#761 at ./task.jl:884
# unsafe_write at ./stream.jl:1154
# unsafe_write at ./io.jl:452 [inlined]
# write at ./strings/io.jl:248 [inlined]
# print at ./strings/io.jl:250
# unknown function (ip: 0x7ce57f7023a6)
# showerror at ./errorshow.jl:152
# unknown function (ip: 0x7ce57f7022e6)
# schedule at ./task.jl:876 [inlined]
# uv_writecb_task at ./stream.jl:1200
# _atexit at ./initdefs.jl:462
# include_string at ./loading.jl:2744 [inlined]
# exec_options at ./client.jl:321
# schedule at ./task.jl:876 [inlined]
# uv_writecb_task at ./stream.jl:1200
# error at ./error.jl:35
# val already in a list#schedule#761 at ./task.jl:884
#
# atexit hook threw an error: ErrorException("schedule: Task not runnable")
# jfptr_uv_writecb_task_66985.1 at /usr/local/lib/julia/sys.so (unknown line)
# _start at ./client.jl:531
# jfptr__atexit_69498.1 at /usr/local/lib/julia/sys.so (unknown line)
# jfptr_uv_writecb_task_66985.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# ijl_atexit_hook at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/init.c:271
# jl_exit_thread0_cb at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/signals-unix.c:517
# schedule at ./task.jl:876 [inlined]
# error at ./error.jl:35
# uv_writecb_task at ./stream.jl:1200
# jfptr__start_73430.1 at /usr/local/lib/julia/sys.so (unknown line)
# jlcapi_uv_writecb_task_67448.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# true_main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:900
# jl_repl_entrypoint at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/jlapi.c:1059
# main at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/cli/loader_exe.c:58
# unknown function (ip: 0x7fcb6590dd8f)
# __libc_start_main at /lib/x86_64-linux-gnu/libc.so.6 (unknown line)
# unknown function (ip: 0x4010b8)
# unknown function (ip: (nil))
# Allocations: 1 (Pool: 1; Big: 0); GC: 0
# uv__write_callbacks at /workspace/srcdir/libuv/src/unix/stream.c:926
# jlcapi_uv_writecb_task_67448.1 at /usr/local/lib/julia/sys.so (unknown line)
# uv__stream_io at /workspace/srcdir/libuv/src/unix/stream.c:1227
# uv__write_callbacks at /workspace/srcdir/libuv/src/unix/stream.c:926
# uv__run_pending at /workspace/srcdir/libuv/src/unix/core.c:824
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:420
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# #schedule#761 at ./task.jl:884
# uv__stream_io at /workspace/srcdir/libuv/src/unix/stream.c:1227
# jfptr_uv_writecb_task_66985.1 at /usr/local/lib/julia/sys.so (unknown line)
# uv__run_pending at /workspace/srcdir/libuv/src/unix/core.c:824
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:420
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# poptask at ./task.jl:1012
# schedule at ./task.jl:876 [inlined]
# uv_writecb_task at ./stream.jl:1200
# poptask at ./task.jl:1012
# jlcapi_uv_writecb_task_67448.1 at /usr/local/lib/julia/sys.so (unknown line)
# uv__write_callbacks at /workspace/srcdir/libuv/src/unix/stream.c:926
# uv__stream_io at /workspace/srcdir/libuv/src/unix/stream.c:1227
# wait at ./task.jl:1021
# uv__run_pending at /workspace/srcdir/libuv/src/unix/core.c:824
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:420
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# wait at ./task.jl:1021
# jfptr_uv_writecb_task_66985.1 at /usr/local/lib/julia/sys.so (unknown line)
# uv_write at ./stream.jl:1081
# poptask at ./task.jl:1012
# uv_write at ./stream.jl:1081
# jlcapi_uv_writecb_task_67448.1 at /usr/local/lib/julia/sys.so (unknown line)
# uv__write_callbacks at /workspace/srcdir/libuv/src/unix/stream.c:926
# uv__stream_io at /workspace/srcdir/libuv/src/unix/stream.c:1227
# unsafe_write at ./stream.jl:1154
# unsafe_write at ./io.jl:452 [inlined]
# write at ./strings/io.jl:248 [inlined]
# print at ./strings/io.jl:250
# unknown function (ip: 0x7d79b9306436)
# showerror at ./errorshow.jl:152
# uv__run_pending at /workspace/srcdir/libuv/src/unix/core.c:824
# unknown function (ip: 0x7d79b9306376)
# uv_run at /workspace/srcdir/libuv/src/unix/core.c:420
# ijl_task_get_next at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/scheduler.c:522
# unsafe_write at ./stream.jl:1154
# wait at ./task.jl:1021
# unsafe_write at ./io.jl:452 [inlined]
# write at ./strings/io.jl:248 [inlined]
# print at ./strings/io.jl:250
# unknown function (ip: 0x790d86cd04e6)
# showerror at ./errorshow.jl:152
# unknown function (ip: 0x790d86cd0426)
# _atexit at ./initdefs.jl:462
# poptask at ./task.jl:1012
# _atexit at ./initdefs.jl:462
# uv_write at ./stream.jl:1081
# jfptr__atexit_69498.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# ijl_atexit_hook at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/init.c:271
# jl_exit_thread0_cb at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/signals-unix.c:517
# jfptr__atexit_69498.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# ijl_atexit_hook at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/init.c:271
# wait at ./task.jl:1021
# jl_exit_thread0_cb at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/signals-unix.c:517
# unsafe_write at ./stream.jl:1154
# unsafe_write at ./io.jl:452 [inlined]
# write at ./strings/io.jl:248 [inlined]
# print at ./strings/io.jl:250
# unknown function (ip: 0x7b14e0cd2a96)
# showerror at ./errorshow.jl:152
# unknown function (ip: 0x7b14e0cd29d6)
# uv_write at ./stream.jl:1081
# _atexit at ./initdefs.jl:462
# unsafe_write at ./stream.jl:1154
# unsafe_write at ./io.jl:452 [inlined]
# write at ./strings/io.jl:248 [inlined]
# print at ./strings/io.jl:250
# unknown function (ip: 0x79bff67ca7b6)
# showerror at ./errorshow.jl:152
# unknown function (ip: 0x79bff67ca6f6)
# jfptr__atexit_69498.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# ijl_atexit_hook at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/init.c:271
# jl_exit_thread0_cb at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/signals-unix.c:517
# _atexit at ./initdefs.jl:462
# jfptr__atexit_69498.1 at /usr/local/lib/julia/sys.so (unknown line)
# jl_apply at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/julia.h:2157 [inlined]
# ijl_atexit_hook at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/init.c:271
# jl_exit_thread0_cb at /cache/build/tester-amdci5-12/julialang/julia-release-1-dot-11/src/signals-unix.c:517
# Failed to precompile Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] to "/root/.julia/compiled/v1.11/Plots/jl_RUHDGo".
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Nothing)
#     @ Base ./loading.jl:3174
#   [3] (::Base.var"#1110#1111"{Base.PkgId})()
#     @ Base ./loading.jl:2579
#   [4] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile /usr/local/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
#   [5] #mkpidlock#6
#     @ /usr/local/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
#   [6] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile /usr/local/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
#   [7] #invokelatest#2
#     @ ./essentials.jl:1057 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:1052 [inlined]
#   [9] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base ./loading.jl:3698
#  [10] maybe_cachefile_lock
#     @ ./loading.jl:3695 [inlined]
#  [11] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:2565
#  [12] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2388
#  [13] #invoke_in_world#3
#     @ ./essentials.jl:1089 [inlined]
#  [14] invoke_in_world
#     @ ./essentials.jl:1086 [inlined]
#  [15] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2375
#  [16] macro expansion
#     @ ./loading.jl:2314 [inlined]
#  [17] macro expansion
#     @ ./lock.jl:273 [inlined]
#  [18] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2271
#  [19] #invoke_in_world#3
#     @ ./essentials.jl:1089 [inlined]
#  [20] invoke_in_world
#     @ ./essentials.jl:1086 [inlined]
#  [21] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2260

# %%
# CG
x1_cg, res1_cg = conjugate_gradient_residuals(A1, b)
x2_cg, res2_cg = conjugate_gradient_residuals(A2, b)
x3_cg, res3_cg = conjugate_gradient_residuals(A3, b)

# GMRES
x1_gm, res1_gm = gmres_residuals(A1, b)
x2_gm, res2_gm = gmres_residuals(A2, b)
x3_gm, res3_gm = gmres_residuals(A3, b)

# BiCGSTAB
x1_bi, res1_bi = bicgstab_residuals(A1, b)
x2_bi, res2_bi = bicgstab_residuals(A2, b)
x3_bi, res3_bi = bicgstab_residuals(A3, b)

# Extract final residuals
final_res_cg_10    = res1_cg[end]
final_res_cg_1000  = res2_cg[end]
final_res_cg_100000  = res3_cg[end]
println(final_res_cg_10)
println(final_res_cg_1000)
println(final_res_cg_100000)

final_res_gm_10    = res1_gm[end]
final_res_gm_1000  = res2_gm[end]
final_res_gm_100000  = res3_gm[end]
println(final_res_gm_10)
println(final_res_gm_1000)
println(final_res_gm_100000)

final_res_bi_10    = res1_bi[end]
final_res_bi_1000  = res2_bi[end]
final_res_bi_100000  = res3_bi[end]
println(final_res_bi_10)
println(final_res_bi_1000)
println(final_res_bi_100000)
# Out:
# Converged in 5 iterations
# Converged in 5 iterations
# Converged in 6 iterations
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# 2.4276833723487815e-16
# 4.0181267127755384e-14
# 1.9565518504412037e-9
# 3.0182194481103634e-16
# 1.7278826712826995e-14
# 1.1603178684643001e-9
# 7.588418996682605e-18
# 1.8865675115385954e-15
# 2.9083651242161397e-9

# %%
t_cg_10 = @elapsed x1_cg, res1_cg = conjugate_gradient_residuals(A1, b)
t_cg_1000 = @elapsed x2_cg, res2_cg = conjugate_gradient_residuals(A2, b)
t_cg_100000 = @elapsed x3_cg, res3_cg = conjugate_gradient_residuals(A3, b)

t_gm_10 = @elapsed x1_gm, res1_gm = gmres_residuals(A1, b)
t_gm_1000 = @elapsed x2_gm, res2_gm = gmres_residuals(A2, b)
t_gm_100000 = @elapsed x3_gm, res3_gm = gmres_residuals(A3, b)

t_bi_10 = @elapsed x1_bi, res1_bi = bicgstab_residuals(A1, b)
t_bi_1000 = @elapsed x2_bi, res2_bi = bicgstab_residuals(A2, b)
t_bi_100000 = @elapsed x3_bi, res3_bi = bicgstab_residuals(A3, b)
# Out:
# Converged in 5 iterations
# Converged in 5 iterations
# Converged in 6 iterations
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# GMRES converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# BiCGSTAB converged in 5 iterations
# 0.000136422

# %%
println("CG time (cond=10): ", t_cg_10)
println("CG time (cond=1000): ", t_cg_1000)
println("CG time (cond=100000): ", t_cg_100000)

println("GMRES time (cond=10): ", t_gm_10)
println("GMRES time (cond=1000): ", t_gm_1000)
println("GMRES time (cond=100000): ", t_gm_100000)

println("BiCGSTAB time (cond=10): ", t_bi_10)
println("BiCGSTAB time (cond=1000): ", t_bi_1000)
println("BiCGSTAB time (cond=100000): ", t_bi_100000)
# Out:
# CG time (cond=10): 0.00014233
# CG time (cond=1000): 0.001170614
# CG time (cond=100000): 0.000123069
# GMRES time (cond=10): 0.000244225
# GMRES time (cond=1000): 0.000241198
# GMRES time (cond=100000): 0.000258137
# BiCGSTAB time (cond=10): 0.00025974
# BiCGSTAB time (cond=1000): 0.000124373
# BiCGSTAB time (cond=100000): 0.000136422
